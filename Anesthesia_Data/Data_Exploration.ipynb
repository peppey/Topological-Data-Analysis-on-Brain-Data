# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV
from gtda.diagrams import PersistenceEntropy, Amplitude, NumberOfPoints, ComplexPolynomial, PersistenceLandscape, HeatKernel, Silhouette, BettiCurve, PairwiseDistance, PersistenceImage 
from gtda.plotting import plot_point_cloud
from scipy.stats import randint
import matplotlib.pyplot as plt
import seaborn as sns
from hausdorff import hausdorff_distance
import numpy as np
import pickle as pickle
import gudhi as gd  
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from numpy.linalg import norm
from sklearn.decomposition import KernelPCA

# %matplotlib inline

# %% [markdown]
# # Load data

# %%
label_list = [0, 1, 2, 3, 4]

# %%
# All features
feature_df  = pd.read_csv("Features/All_Features.csv")

# %% [markdown]
# # Finding clusters in Features

# %%
feature_df.columns
# Out:
# Index(['Unnamed: 0', 'EEG_Persistence Entropy_Dim_0', 'EEG_Amplitude_Dim_0',
#        'EEG_No_Points_Dim_0', 'EEG_Largest_Persistence_Dim_0',
#        'EEG_Persistence Entropy_Dim_1', 'EEG_Amplitude_Dim_1',
#        'EEG_No_Points_Dim_1', 'EEG_Largest_Persistence_Dim_1',
#        'EEG_Persistence Entropy_Dim_2',
#        ...
#        'Kernel_Intensity_Dim1', 'L1_Norm_PDDim0', 'L1_Norm_PDDim1',
#        'L1_Norm_BCDim0', 'L1_Norm_BCDim1', 'AC_coordinate_cc1',
#        'AC_coordinate_cc2', 'AC_coordinate_cc3', 'AC_coordinate_cc4',
#        'Subject_BI'],
#       dtype='object', length=678)

# %%
subject_df = feature_df[feature_df["Subject_BI"] == 1]

# %% [markdown]
# ### Brain Imaging

# %%
# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the points
ax.scatter(subject_df['AC_coordinate_cc2'], subject_df['AC_coordinate_cc3'], subject_df['AC_coordinate_cc4'])

# Adding labels and title
ax.set_xlabel('AC coordinate 2')
ax.set_ylabel('AC coordinate 3')
ax.set_zlabel('AC coordinate 4')
ax.set_title('3 Brain Imaging Adcock Coordinates')

# Displaying the plot
plt.show()

# %%
# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the points
ax.scatter(subject_df['AC_coordinate_cc1'], subject_df['AC_coordinate_cc2'], subject_df['AC_coordinate_cc3'])

# Adding labels and title
ax.set_xlabel('AC coordinate 1')
ax.set_ylabel('AC coordinate 2')
ax.set_zlabel('AC coordinate 3')
ax.set_title('3 Brain Imaging Adcock Coordinates')

# Displaying the plot
plt.show()

# %% [markdown]
# ## EEG

# %%
# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the points
ax.scatter(subject_df['EEG_AC_coordinate_cc1'], subject_df['EEG_AC_coordinate_cc2'], subject_df['EEG_AC_coordinate_cc3'])

# Adding labels and title
ax.set_xlabel('AC coordinate 1')
ax.set_ylabel('AC coordinate 2')
ax.set_zlabel('AC coordinate 3')
ax.set_title('3 Brain Imaging Adcock Coordinates')

# Displaying the plot
plt.show()
